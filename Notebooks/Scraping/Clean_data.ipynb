# %%
import os
import re

def preprocess_markdown(text: str) -> str:
    """
    Функция для предобработки Markdown-текста.
    Выполняет следующие шаги:
      1. Заменяет блоки кода, заключённые в тройные обратные кавычки, на метку [CODE].
      2. Заменяет изображения на их alt-текст.
      3. Заменяет ссылки, оставляя только текст ссылки.
      4. Удаляет символы заголовков (#) в начале строки.
      5. Убирает маркеры маркированных (-, *) и нумерованных списков.
      6. Убирает разметку для выделения (жирный/курсив) – удаляет звездочки.
      7. Убирает обратные кавычки для встроенного кода.
      8. Убирает символы цитирования (>) в начале строки.
      9. Заменяет горизонтальные линии (например, '---') на разделитель '===='.
      10. Усечение ссылок: для каждого URL оставляет только часть до последнего символа "/".
      11. Удаляет раздел "Содержание" и всё, что к нему относится.
    """
    # 1. Заменяем блоки кода на метку [CODE]
    text = re.sub(r'```[\s\S]*?```', '[CODE]', text)
    # 2. Заменяем изображения на alt-текст
    text = re.sub(r'!\[([^\]]*)\]\([^)]*\)', r'\1', text)
    # 3. Заменяем ссылки, оставляя только текст ссылки
    text = re.sub(r'\[([^\]]+)\]\([^)]*\)', r'\1', text)
    # 4. Удаляем символы заголовков
    text = re.sub(r'^#+\s*', '', text, flags=re.MULTILINE)
    # 5. Обработка маркеров списков
    text = re.sub(r'^\s*[-*]\s+', '- ', text, flags=re.MULTILINE)
    text = re.sub(r'^\s*\d+\.\s+', '', text, flags=re.MULTILINE)
    # 6. Убираем разметку жирного и курсива
    text = re.sub(r'\*\*(.*?)\*\*', r'\1', text)
    text = re.sub(r'\*(.*?)\*', r'\1', text)
    # 7. Убираем обратные кавычки вокруг кода
    text = re.sub(r'`([^`]+)`', r'\1', text)
    # 8. Удаляем символы цитирования
    text = re.sub(r'^\s*>\s+', '', text, flags=re.MULTILINE)
    # 9. Заменяем горизонтальные линии на явный разделитель
    text = re.sub(r'^---\s*$', '====', text, flags=re.MULTILINE)
    # 10. Усечение ссылок: удаляем всё, что находится после последнего '/'
    text = trim_urls(text)
    # 11. Удаляем раздел "Содержание" и всё, что к нему относится
    text = re.sub(r'(^#+\s*Содержание.*?)(?=^#+\s*\S|$)', '', text, flags=re.DOTALL | re.MULTILINE | re.IGNORECASE)
    
    return text

def trim_urls(text: str) -> str:
    """
    Находит все URL в тексте (начинающиеся с http или https) и усечёт их,
    оставляя только часть до последнего символа "/". Например, из:
      https://sappo.ru/blog/.../21720/>  
    останется:
      https://sappo.ru/blog/.../21720/
    """
    # Шаблон, захватывающий URL до пробельного символа или знака конца строки
    url_pattern = re.compile(r'(https?://\S+)')
    
    def trim(match):
        url = match.group(0)
        last_slash = url.rfind('/')
        if last_slash != -1:
            return url[:last_slash+1]
        return url

    return url_pattern.sub(trim, text)

if __name__ == '__main__':
    input_dir = '/Users/sergey/Desktop/Voise_RAG/DATA/articles'
    
    # Обрабатываем все файлы с расширением .md в указанной директории
    for filename in os.listdir(input_dir):
        if filename.endswith('.md'):
            file_path = os.path.join(input_dir, filename)
            with open(file_path, 'r', encoding='utf-8') as f:
                markdown_text = f.read()
            
            cleaned_text = preprocess_markdown(markdown_text)
            # Формируем имя выходного файла с суффиксом _cleaned, чтобы сохранить исходник нетронутым
            output_file = os.path.join(input_dir, filename.replace('.md', '_cleaned.md'))
            
            with open(output_file, 'w', encoding='utf-8') as f:
                f.write(cleaned_text)
            
            print(f'Обработан файл: {file_path}\nСохранён как: {output_file}\n')
# Out:
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/ukhod-za-kozhey.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/ukhod-za-kozhey_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/khimchistka-salona-avtomobilya-svoimi-rukami.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/khimchistka-salona-avtomobilya-svoimi-rukami_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/ukhod-za-plastikovymi-elementami-salona.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/ukhod-za-plastikovymi-elementami-salona_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-pravilno-otpolirovat-lobovoe-steklo.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-pravilno-otpolirovat-lobovoe-steklo_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-izbavitsya-ot-zapaha-v-salone-avto.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-izbavitsya-ot-zapaha-v-salone-avto_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/luchshiy-antidozhd-dlya-avtomobilya-kakoy-vybrat.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/luchshiy-antidozhd-dlya-avtomobilya-kakoy-vybrat_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-bystro-i-prosto-pridat-kuzovu-blesk.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-bystro-i-prosto-pridat-kuzovu-blesk_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/test-nabora-dlya-obnovleniya-kozhi-v-salone.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/test-nabora-dlya-obnovleniya-kozhi-v-salone_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/dorozhnyy-nabor-avtokosmetiki-dlya-ukhoda-za-avtomobilem-chto-nuzhno-vzyat-s-soboy.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/dorozhnyy-nabor-avtokosmetiki-dlya-ukhoda-za-avtomobilem-chto-nuzhno-vzyat-s-soboy_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/skoro-zima-zapasaemsya-razmorazhivatelyami-stekol.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/skoro-zima-zapasaemsya-razmorazhivatelyami-stekol_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/chem-chernit-rezinu.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/chem-chernit-rezinu_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-pravilno-chistit-i-ukhazhivat-za-khromirovannymi-elementami-kuzova-avtomobilya.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-pravilno-chistit-i-ukhazhivat-za-khromirovannymi-elementami-kuzova-avtomobilya_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/letnyaya-zakupka-avtokhimiey-v-sappo.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/letnyaya-zakupka-avtokhimiey-v-sappo_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/samostoyatelnyy-ukhod-za-avto-s-naborom-interior-box-ot-smart-open.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/samostoyatelnyy-ukhod-za-avto-s-naborom-interior-box-ot-smart-open_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-legko-i-bystro-pochistit-kozhu-i-alkantaru.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-legko-i-bystro-pochistit-kozhu-i-alkantaru_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/chistka-sidenij-avtomobilya-osnovnye-pravila-i-sovety.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/chistka-sidenij-avtomobilya-osnovnye-pravila-i-sovety_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/samostoyatelnaya-obrabotka-lkp-voskom.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/samostoyatelnaya-obrabotka-lkp-voskom_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-ubrat-rzhavchinu-s-kuzova.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-ubrat-rzhavchinu-s-kuzova_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/moyka-kolesnykh-diskov.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/moyka-kolesnykh-diskov_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/samostoyatelnaya-moyka-dvigatelya.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/samostoyatelnaya-moyka-dvigatelya_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/luchshie-aromatizatory-dlya-avtomobilya.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/luchshie-aromatizatory-dlya-avtomobilya_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kakie-carapiny-mozhno-ustranit-s-pomoshyu-polirovki.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kakie-carapiny-mozhno-ustranit-s-pomoshyu-polirovki_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-uhazhivat-za-kozhanym-salonom-avtomobilya.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-uhazhivat-za-kozhanym-salonom-avtomobilya_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/idei-podarkov-dlya-muzhchiny-avtolyubitelya.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/idei-podarkov-dlya-muzhchiny-avtolyubitelya_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-ubrat-carapiny-s-plastika-salona-avtomobilya.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-ubrat-carapiny-s-plastika-salona-avtomobilya_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/sappo-moyka-kolesnykh-diskov.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/sappo-moyka-kolesnykh-diskov_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/chto-takoe-polirovka-avtomobilya.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/chto-takoe-polirovka-avtomobilya_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/samostoyatelnaya-obrabotka-stekol-antidozhdem.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/samostoyatelnaya-obrabotka-stekol-antidozhdem_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/chem-otmyt-nasekomyh-s-avtomobilya.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/chem-otmyt-nasekomyh-s-avtomobilya_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-pravilno-myt-dvigatel-avtomobilya.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-pravilno-myt-dvigatel-avtomobilya_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-otpolirovat-avtomobil-svoimi-rukami.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-otpolirovat-avtomobil-svoimi-rukami_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/dachnyy-deteyler.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/dachnyy-deteyler_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak_samostoyatelno_nanesti_antidojd.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak_samostoyatelno_nanesti_antidojd_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/pokrytie-avtomobilya-keramikoy-plyusy-i-minusy.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/pokrytie-avtomobilya-keramikoy-plyusy-i-minusy_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-vybrat-dvorniki-dlya-avtomobilya-sovety-po-vyboru.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-vybrat-dvorniki-dlya-avtomobilya-sovety-po-vyboru_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-otpolirovat-fary.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-otpolirovat-fary_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-snyat-tonirovku-so-stekla-avtomobilya.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-snyat-tonirovku-so-stekla-avtomobilya_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/zhidkoe-steklo-ili-keramika-chto-luchshe-dlya-zashchity-avtomobilya.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/zhidkoe-steklo-ili-keramika-chto-luchshe-dlya-zashchity-avtomobilya_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/mikrofibry-dlya-chego-nuzhny-kakie-byvayut-kak-pravilno-vybrat-i-kak-ukhazhivat.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/mikrofibry-dlya-chego-nuzhny-kakie-byvayut-kak-pravilno-vybrat-i-kak-ukhazhivat_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/vosk-dlya-avtomobilya-kak-ego-pravilno-nanosit-i-zachem-nuzhen.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/vosk-dlya-avtomobilya-kak-ego-pravilno-nanosit-i-zachem-nuzhen_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/chem-zashchitit-kuzov-avtomobilya-zimoy-kakoe-pokrytie-dlya-lkp-luchshe.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/chem-zashchitit-kuzov-avtomobilya-zimoy-kakoe-pokrytie-dlya-lkp-luchshe_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-podgotovit-avtomobil-k-vesne.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-podgotovit-avtomobil-k-vesne_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/moyka-dvigatelya-zachem-i-kak-chasto-neobkhodimo-myt-podkapotnoe-prostranstvo.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/moyka-dvigatelya-zachem-i-kak-chasto-neobkhodimo-myt-podkapotnoe-prostranstvo_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/abrazivnaya-glina-dlya-kuzova-kak-ispolzovat-i-dlya-chego-on-nuzhna.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/abrazivnaya-glina-dlya-kuzova-kak-ispolzovat-i-dlya-chego-on-nuzhna_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-otmyt-bitum-s-kuzova-avtomobilya.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-otmyt-bitum-s-kuzova-avtomobilya_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/moyka-avtomobilya-v-zimnee-vremya.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/moyka-avtomobilya-v-zimnee-vremya_cleaned.md
#
# Обработан файл: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-delayut-himchistku-salona-avtomobilya.md
# Сохранён как: /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-delayut-himchistku-salona-avtomobilya_cleaned.md

# %%
import os
import shutil

# Директория с исходными файлами
input_dir = '/Users/sergey/Desktop/Voise_RAG/DATA/articles'
# Директория для сохранения файлов с окончанием "cleaned.md"
output_folder = os.path.join(input_dir, 'cleaned')
os.makedirs(output_folder, exist_ok=True)

# Перебор всех файлов в исходной директории
for filename in os.listdir(input_dir):
    if filename.endswith('cleaned.md'):
        src_file = os.path.join(input_dir, filename)
        dest_file = os.path.join(output_folder, filename)
        shutil.copy(src_file, dest_file)
        print(f'Файл {src_file} скопирован в {dest_file}')
# Out:
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-ubrat-carapiny-s-plastika-salona-avtomobilya_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-ubrat-carapiny-s-plastika-salona-avtomobilya_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/vosk-dlya-avtomobilya-kak-ego-pravilno-nanosit-i-zachem-nuzhen_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/vosk-dlya-avtomobilya-kak-ego-pravilno-nanosit-i-zachem-nuzhen_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/luchshie-aromatizatory-dlya-avtomobilya_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/luchshie-aromatizatory-dlya-avtomobilya_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/mikrofibry-dlya-chego-nuzhny-kakie-byvayut-kak-pravilno-vybrat-i-kak-ukhazhivat_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/mikrofibry-dlya-chego-nuzhny-kakie-byvayut-kak-pravilno-vybrat-i-kak-ukhazhivat_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/ukhod-za-kozhey_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/ukhod-za-kozhey_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/samostoyatelnaya-obrabotka-lkp-voskom_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/samostoyatelnaya-obrabotka-lkp-voskom_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/abrazivnaya-glina-dlya-kuzova-kak-ispolzovat-i-dlya-chego-on-nuzhna_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/abrazivnaya-glina-dlya-kuzova-kak-ispolzovat-i-dlya-chego-on-nuzhna_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-vybrat-dvorniki-dlya-avtomobilya-sovety-po-vyboru_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-vybrat-dvorniki-dlya-avtomobilya-sovety-po-vyboru_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-legko-i-bystro-pochistit-kozhu-i-alkantaru_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-legko-i-bystro-pochistit-kozhu-i-alkantaru_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/chistka-sidenij-avtomobilya-osnovnye-pravila-i-sovety_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/chistka-sidenij-avtomobilya-osnovnye-pravila-i-sovety_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-ubrat-rzhavchinu-s-kuzova_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-ubrat-rzhavchinu-s-kuzova_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/dorozhnyy-nabor-avtokosmetiki-dlya-ukhoda-za-avtomobilem-chto-nuzhno-vzyat-s-soboy_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/dorozhnyy-nabor-avtokosmetiki-dlya-ukhoda-za-avtomobilem-chto-nuzhno-vzyat-s-soboy_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/samostoyatelnyy-ukhod-za-avto-s-naborom-interior-box-ot-smart-open_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/samostoyatelnyy-ukhod-za-avto-s-naborom-interior-box-ot-smart-open_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-otpolirovat-fary_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-otpolirovat-fary_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/skoro-zima-zapasaemsya-razmorazhivatelyami-stekol_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/skoro-zima-zapasaemsya-razmorazhivatelyami-stekol_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/samostoyatelnaya-obrabotka-stekol-antidozhdem_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/samostoyatelnaya-obrabotka-stekol-antidozhdem_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-otmyt-bitum-s-kuzova-avtomobilya_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-otmyt-bitum-s-kuzova-avtomobilya_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/idei-podarkov-dlya-muzhchiny-avtolyubitelya_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/idei-podarkov-dlya-muzhchiny-avtolyubitelya_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/chto-takoe-polirovka-avtomobilya_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/chto-takoe-polirovka-avtomobilya_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/ukhod-za-plastikovymi-elementami-salona_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/ukhod-za-plastikovymi-elementami-salona_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/luchshiy-antidozhd-dlya-avtomobilya-kakoy-vybrat_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/luchshiy-antidozhd-dlya-avtomobilya-kakoy-vybrat_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-bystro-i-prosto-pridat-kuzovu-blesk_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-bystro-i-prosto-pridat-kuzovu-blesk_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/test-nabora-dlya-obnovleniya-kozhi-v-salone_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/test-nabora-dlya-obnovleniya-kozhi-v-salone_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/dachnyy-deteyler_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/dachnyy-deteyler_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-izbavitsya-ot-zapaha-v-salone-avto_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-izbavitsya-ot-zapaha-v-salone-avto_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/sappo-moyka-kolesnykh-diskov_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/sappo-moyka-kolesnykh-diskov_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-snyat-tonirovku-so-stekla-avtomobilya_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-snyat-tonirovku-so-stekla-avtomobilya_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/zhidkoe-steklo-ili-keramika-chto-luchshe-dlya-zashchity-avtomobilya_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/zhidkoe-steklo-ili-keramika-chto-luchshe-dlya-zashchity-avtomobilya_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/chem-otmyt-nasekomyh-s-avtomobilya_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/chem-otmyt-nasekomyh-s-avtomobilya_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kakie-carapiny-mozhno-ustranit-s-pomoshyu-polirovki_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kakie-carapiny-mozhno-ustranit-s-pomoshyu-polirovki_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/samostoyatelnaya-moyka-dvigatelya_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/samostoyatelnaya-moyka-dvigatelya_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-pravilno-otpolirovat-lobovoe-steklo_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-pravilno-otpolirovat-lobovoe-steklo_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak_samostoyatelno_nanesti_antidojd_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak_samostoyatelno_nanesti_antidojd_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/moyka-kolesnykh-diskov_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/moyka-kolesnykh-diskov_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/chem-chernit-rezinu_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/chem-chernit-rezinu_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/pokrytie-avtomobilya-keramikoy-plyusy-i-minusy_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/pokrytie-avtomobilya-keramikoy-plyusy-i-minusy_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-otpolirovat-avtomobil-svoimi-rukami_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-otpolirovat-avtomobil-svoimi-rukami_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-pravilno-chistit-i-ukhazhivat-za-khromirovannymi-elementami-kuzova-avtomobilya_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-pravilno-chistit-i-ukhazhivat-za-khromirovannymi-elementami-kuzova-avtomobilya_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/moyka-avtomobilya-v-zimnee-vremya_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/moyka-avtomobilya-v-zimnee-vremya_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-uhazhivat-za-kozhanym-salonom-avtomobilya_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-uhazhivat-za-kozhanym-salonom-avtomobilya_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/moyka-dvigatelya-zachem-i-kak-chasto-neobkhodimo-myt-podkapotnoe-prostranstvo_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/moyka-dvigatelya-zachem-i-kak-chasto-neobkhodimo-myt-podkapotnoe-prostranstvo_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-delayut-himchistku-salona-avtomobilya_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-delayut-himchistku-salona-avtomobilya_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-pravilno-myt-dvigatel-avtomobilya_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-pravilno-myt-dvigatel-avtomobilya_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/chem-zashchitit-kuzov-avtomobilya-zimoy-kakoe-pokrytie-dlya-lkp-luchshe_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/chem-zashchitit-kuzov-avtomobilya-zimoy-kakoe-pokrytie-dlya-lkp-luchshe_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/khimchistka-salona-avtomobilya-svoimi-rukami_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/khimchistka-salona-avtomobilya-svoimi-rukami_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/kak-podgotovit-avtomobil-k-vesne_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-podgotovit-avtomobil-k-vesne_cleaned.md
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/letnyaya-zakupka-avtokhimiey-v-sappo_cleaned.md скопирован в /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/letnyaya-zakupka-avtokhimiey-v-sappo_cleaned.md

# %%
def remove_duplicate_links(text: str) -> str:
    """
    Функция удаляет повторяющиеся URL в тексте, оставляя только первое вхождение каждого URL.
    Для поиска URL используется шаблон, который находит все подстроки, начинающиеся с http или https.
    """
    seen = set()

    def repl(match):
        url = match.group(0)
        if url in seen:
            # Если URL уже встречался, возвращаем пустую строку для удаления
            return ""
        seen.add(url)
        return url

    # Ищем все подстроки, соответствующие URL, и применяем замену через функцию repl
    return re.sub(r'(https?://\S+)', repl, text)

if __name__ == '__main__':
    # Директория с обработанными файлами, оканчивающимися на cleaned.md
    cleaned_dir = '/Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned'
    
    # Перебор всех файлов в указанной директории
    for filename in os.listdir(cleaned_dir):
        if filename.endswith('cleaned.md'):
            file_path = os.path.join(cleaned_dir, filename)
            with open(file_path, 'r', encoding='utf-8') as f:
                content = f.read()
            
            new_content = remove_duplicate_links(content)
            
            # Перезаписываем файл новыми данными
            with open(file_path, 'w', encoding='utf-8') as f:
                f.write(new_content)
            
            print(f'Файл {file_path} обработан (удалены дубликаты ссылок).')
# Out:
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-ubrat-carapiny-s-plastika-salona-avtomobilya_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/vosk-dlya-avtomobilya-kak-ego-pravilno-nanosit-i-zachem-nuzhen_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/luchshie-aromatizatory-dlya-avtomobilya_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/mikrofibry-dlya-chego-nuzhny-kakie-byvayut-kak-pravilno-vybrat-i-kak-ukhazhivat_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/ukhod-za-kozhey_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/samostoyatelnaya-obrabotka-lkp-voskom_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/abrazivnaya-glina-dlya-kuzova-kak-ispolzovat-i-dlya-chego-on-nuzhna_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-vybrat-dvorniki-dlya-avtomobilya-sovety-po-vyboru_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-legko-i-bystro-pochistit-kozhu-i-alkantaru_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/chistka-sidenij-avtomobilya-osnovnye-pravila-i-sovety_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-ubrat-rzhavchinu-s-kuzova_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/dorozhnyy-nabor-avtokosmetiki-dlya-ukhoda-za-avtomobilem-chto-nuzhno-vzyat-s-soboy_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/samostoyatelnyy-ukhod-za-avto-s-naborom-interior-box-ot-smart-open_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-otpolirovat-fary_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/skoro-zima-zapasaemsya-razmorazhivatelyami-stekol_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/samostoyatelnaya-obrabotka-stekol-antidozhdem_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-otmyt-bitum-s-kuzova-avtomobilya_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/idei-podarkov-dlya-muzhchiny-avtolyubitelya_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/chto-takoe-polirovka-avtomobilya_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/ukhod-za-plastikovymi-elementami-salona_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/luchshiy-antidozhd-dlya-avtomobilya-kakoy-vybrat_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-bystro-i-prosto-pridat-kuzovu-blesk_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/test-nabora-dlya-obnovleniya-kozhi-v-salone_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/dachnyy-deteyler_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-izbavitsya-ot-zapaha-v-salone-avto_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/sappo-moyka-kolesnykh-diskov_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-snyat-tonirovku-so-stekla-avtomobilya_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/zhidkoe-steklo-ili-keramika-chto-luchshe-dlya-zashchity-avtomobilya_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/chem-otmyt-nasekomyh-s-avtomobilya_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kakie-carapiny-mozhno-ustranit-s-pomoshyu-polirovki_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/samostoyatelnaya-moyka-dvigatelya_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-pravilno-otpolirovat-lobovoe-steklo_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak_samostoyatelno_nanesti_antidojd_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/moyka-kolesnykh-diskov_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/chem-chernit-rezinu_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/pokrytie-avtomobilya-keramikoy-plyusy-i-minusy_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-otpolirovat-avtomobil-svoimi-rukami_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-pravilno-chistit-i-ukhazhivat-za-khromirovannymi-elementami-kuzova-avtomobilya_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/moyka-avtomobilya-v-zimnee-vremya_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-uhazhivat-za-kozhanym-salonom-avtomobilya_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/moyka-dvigatelya-zachem-i-kak-chasto-neobkhodimo-myt-podkapotnoe-prostranstvo_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-delayut-himchistku-salona-avtomobilya_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-pravilno-myt-dvigatel-avtomobilya_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/chem-zashchitit-kuzov-avtomobilya-zimoy-kakoe-pokrytie-dlya-lkp-luchshe_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/khimchistka-salona-avtomobilya-svoimi-rukami_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/kak-podgotovit-avtomobil-k-vesne_cleaned.md обработан (удалены дубликаты ссылок).
# Файл /Users/sergey/Desktop/Voise_RAG/DATA/articles/cleaned/letnyaya-zakupka-avtokhimiey-v-sappo_cleaned.md обработан (удалены дубликаты ссылок).
